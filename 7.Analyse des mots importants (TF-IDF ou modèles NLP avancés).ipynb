# %%
import numpy as np

labels_unique = y.unique()
for label in labels_unique:
    idx = np.where(y == label)[0]
    mean_tfidf = X[idx].mean(axis=0).A1  # moyenne TF-IDF
    top_idx = mean_tfidf.argsort()[-10:][::-1]
    top_words = [tfidf_features[i] for i in top_idx]
    print(f"Label: {label} → Top mots : {top_words}")
